# %% [markdown]
# <a href="https://colab.research.google.com/github/MananDesai2997/MananDesai2997/blob/main/HPO%20ORing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import io
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-475b90ac-c706-4700-9756-41a1d421984b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-475b90ac-c706-4700-9756-41a1d421984b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HPO ORing.csv to HPO ORing.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['HPO ORing.csv']))

# %%
df.head()
# Out:
#    THICKNESS AVERAGE  ...  HE LEAK TEST
# 0              0.172  ...          True
# 1              0.172  ...          True
# 2              0.172  ...          True
# 3              0.172  ...          True
# 4              0.170  ...         False
#
# [5 rows x 4 columns]

# %%
df.shape
# Out:
# (1978, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1978 entries, 0 to 1977
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   THICKNESS AVERAGE              1978 non-null   float64
#  1   SURFACE FINISH TOP AVERAGE     1978 non-null   float64
#  2   SURFACE FINISH BOTTOM AVERAGE  1978 non-null   float64
#  3   HE LEAK TEST                   1978 non-null   bool
# dtypes: bool(1), float64(3)
# memory usage: 48.4 KB

# %%
df_True = df.loc[df['HE LEAK TEST']=='True']
df_False = df.loc[df['HE LEAK TEST']=='False']

# %%
plt.plot(df_True['THICKNESS AVERAGE'],np.zeros_like(df_True['THICKNESS AVERAGE']), 'o')

# %%
plt.plot(df_True['THICKNESS AVERAGE'],np.zeros_like(df_True['THICKNESS AVERAGE']), 'o')
plt.plot(df_True['SURFACE FINISH TOP AVERAGE'],np.zeros_like(df_True['SURFACE FINISH TOP AVERAGE']), 'o')
plt.plot(df_True['SURFACE FINISH BOTTOM AVERAGE'],np.zeros_like(df_True['SURFACE FINISH BOTTOM AVERAGE']), 'o')
plt.show()

# %%
sns.FacetGrid(df,hue="HE LEAK TEST",size=6).map(plt.scatter,"THICKNESS AVERAGE", "SURFACE FINISH TOP AVERAGE").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="HE LEAK TEST",size=6).map(plt.scatter,"THICKNESS AVERAGE", "SURFACE FINISH BOTTOM AVERAGE").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="HE LEAK TEST",size=6).map(plt.scatter,"SURFACE FINISH BOTTOM AVERAGE", "SURFACE FINISH TOP AVERAGE").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, hue='HE LEAK TEST', size =2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
